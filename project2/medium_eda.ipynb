# %%
import numpy as np
import utils
np.set_printoptions(linewidth=np.inf)

# %%
def get_pv(idx):
    idx = idx - 1
    v = idx // 500
    p = idx % 500
    return p, v

# %%
data = utils.read_data('medium')
states = data[:, 0]
actions = data[:, 1]
rewards = data[:, 2]

unique_rewards = np.unique(rewards)
reward_to_idx = {reward: idx for idx, reward in enumerate(unique_rewards)}
idx_to_reward = {idx: reward for reward, idx in reward_to_idx.items()}
reward_idx = np.array([reward_to_idx[r] for r in rewards])

next_states = data[:, 3]
states_pv = np.array([get_pv(s) for s in states])
next_states_pv = np.array([get_pv(s) for s in next_states])
actions = actions.reshape(-1, 1)       # Shape (N, 1)
rewards = rewards.reshape(-1, 1)       # Shape (N, 1)
data_ = np.hstack([states_pv, actions, next_states_pv, rewards])
max_reward = data_[data_[:, -1] == 100_000]
col_max = np.max(data_, axis=0)
achieved = data_[data_[:, 3] >= 466]
achieved = achieved[achieved[:, -1].argsort()]

# %%
u_s_p = np.unique(states_pv[:, 0])
u_ns_p = np.unique(next_states_pv[:, 0])
u_s_v = np.unique(states_pv[:, 1])
u_ns_v = np.unique(next_states_pv[:, 1])

print(u_s_p.shape)
print(u_ns_p.shape)
print(u_s_v.shape)
print(u_ns_v.shape)
# Out:
# (466,)
# (473,)
# (98,)
# (98,)

# %%
sorted_data = data_[np.lexsort((data_[:, 2], data_[:, 1], data_[:, 0]))]

unique_combinations = {}
for row in sorted_data:
    key = (row[0], row[1], row[2])
    result = (row[3], row[4])
    
    if key not in unique_combinations:
        unique_combinations[key] = {}
    if result not in unique_combinations[key]:
        unique_combinations[key][result] = 0
    unique_combinations[key][result] += 1

multi_resulting_params = {k: v for k, v in unique_combinations.items() if len(v) > 1}

for key, results in multi_resulting_params.items():
    print(f"Combination {key} has multiple resulting parameters with counts: {results}")
# Out:
# Combination (0.0, 50.0, 4.0) has multiple resulting parameters with counts: {(0.0, 51.0): 16, (0.0, 52.0): 1}
# Combination (0.0, 50.0, 5.0) has multiple resulting parameters with counts: {(0.0, 51.0): 16, (1.0, 52.0): 2, (1.0, 51.0): 1}
# Combination (0.0, 51.0, 4.0) has multiple resulting parameters with counts: {(1.0, 53.0): 7, (1.0, 52.0): 8}
# Combination (0.0, 51.0, 5.0) has multiple resulting parameters with counts: {(1.0, 52.0): 48, (1.0, 53.0): 9, (2.0, 53.0): 1}
# Combination (1.0, 45.0, 3.0) has multiple resulting parameters with counts: {(0.0, 50.0): 1, (0.0, 46.0): 1}
# Combination (1.0, 47.0, 3.0) has multiple resulting parameters with counts: {(1.0, 48.0): 1, (0.0, 48.0): 1}
# Combination (1.0, 52.0, 3.0) has multiple resulting parameters with counts: {(3.0, 53.0): 1, (2.0, 53.0): 5}
# Combination (1.0, 52.0, 4.0) has multiple resulting parameters with counts: {(2.0, 54.0): 3, (3.0, 54.0): 1, (2.0, 53.0): 1}
# Combination (1.0, 52.0, 5.0) has multiple resulting parameters with counts: {(2.0, 54.0): 49, (3.0, 54.0): 1, (2.0, 53.0): 1}
# Combination (1.0, 52.0, 6.0) has multiple resulting parameters with counts: {(3.0, 54.0): 2, (2.0, 54.0): 8}
# Combination (1.0, 53.0, 3.0) has multiple resulting parameters with counts: {(3.0, 54.0): 7, (2.0, 54.0): 2}
# Combination (1.0, 53.0, 4.0) has multiple resulting parameters with counts: {(2.0, 54.0): 1, (3.0, 54.0): 3, (3.0, 55.0): 1}
# Combination (1.0, 53.0, 5.0) has multiple resulting parameters with counts: {(3.0, 54.0): 6, (3.0, 55.0): 3}
# Combination (2.0, 53.0, 4.0) has multiple resulting parameters with counts: {(4.0, 55.0): 1, (3.0, 54.0): 1, (4.0, 54.0): 1}
# Combination (2.0, 54.0, 3.0) has multiple resulting parameters with counts: {(4.0, 55.0): 3, (5.0, 55.0): 1}
# Combination (2.0, 54.0, 4.0) has multiple resulting parameters with counts: {(4.0, 55.0): 5, (5.0, 56.0): 1}
# Combination (2.0, 54.0, 5.0) has multiple resulting parameters with counts: {(5.0, 56.0): 45, (4.0, 55.0): 3}
# Combination (2.0, 54.0, 6.0) has multiple resulting parameters with counts: {(4.0, 56.0): 1, (5.0, 56.0): 4}
# Combination (3.0, 40.0, 3.0) has multiple resulting parameters with counts: {(1.0, 41.0): 1, (0.0, 41.0): 1}
# Combination (3.0, 54.0, 4.0) has multiple resulting parameters with counts: {(5.0, 55.0): 6, (5.0, 56.0): 4}
# Combination (3.0, 54.0, 5.0) has multiple resulting parameters with counts: {(5.0, 56.0): 2, (6.0, 56.0): 1}
# Combination (3.0, 54.0, 6.0) has multiple resulting parameters with counts: {(5.0, 56.0): 3, (6.0, 56.0): 1}
# Combination (3.0, 55.0, 3.0) has multiple resulting parameters with counts: {(5.0, 56.0): 1, (6.0, 56.0): 1}
# Combination (3.0, 55.0, 6.0) has multiple resulting parameters with counts: {(6.0, 57.0): 2, (5.0, 57.0): 1}
# Combination (4.0, 36.0, 3.0) has multiple resulting parameters with counts: {(0.0, 50.0): 2, (0.0, 37.0): 1}
# Combination (4.0, 55.0, 3.0) has multiple resulting parameters with counts: {(7.0, 56.0): 4, (6.0, 56.0): 2}
# Combination (4.0, 55.0, 4.0) has multiple resulting parameters with counts: {(7.0, 56.0): 1, (7.0, 57.0): 1}
# Combination (4.0, 55.0, 5.0) has multiple resulting parameters with counts: {(7.0, 57.0): 3, (6.0, 57.0): 1, (7.0, 56.0): 1, (6.0, 56.0): 1}
# Combination (4.0, 55.0, 6.0) has multiple resulting parameters with counts: {(6.0, 57.0): 1, (7.0, 57.0): 1}
# Combination (5.0, 34.0, 1.0) has multiple resulting parameters with counts: {(0.0, 50.0): 1, (0.0, 35.0): 2}
# Combination (5.0, 37.0, 3.0) has multiple resulting parameters with counts: {(0.0, 38.0): 2, (2.0, 38.0): 1}
# Combination (5.0, 43.0, 3.0) has multiple resulting parameters with counts: {(3.0, 44.0): 1, (4.0, 44.0): 1}
# Combination (5.0, 55.0, 4.0) has multiple resulting parameters with counts: {(7.0, 57.0): 3, (7.0, 56.0): 1}
# Combination (5.0, 55.0, 6.0) has multiple resulting parameters with counts: {(8.0, 57.0): 1, (7.0, 57.0): 2}
# Combination (5.0, 56.0, 4.0) has multiple resulting parameters with counts: {(8.0, 57.0): 4, (7.0, 57.0): 1}
# Combination (5.0, 56.0, 5.0) has multiple resulting parameters with counts: {(7.0, 57.0): 45, (8.0, 57.0): 1, (8.0, 58.0): 2}
# Combination (5.0, 56.0, 6.0) has multiple resulting parameters with counts: {(8.0, 58.0): 4, (7.0, 58.0): 1}
# Combination (6.0, 38.0, 3.0) has multiple resulting parameters with counts: {(3.0, 39.0): 2, (2.0, 39.0): 1}
# Combination (6.0, 39.0, 3.0) has multiple resulting parameters with counts: {(2.0, 40.0): 1, (3.0, 40.0): 1}
# Combination (6.0, 56.0, 3.0) has multiple resulting parameters with counts: {(8.0, 57.0): 1, (9.0, 57.0): 3}
# Combination (7.0, 31.0, 3.0) has multiple resulting parameters with counts: {(1.0, 33.0): 1, (1.0, 32.0): 1}
# Combination (7.0, 32.0, 3.0) has multiple resulting parameters with counts: {(1.0, 33.0): 1, (1.0, 34.0): 1}
# Combination (7.0, 42.0, 3.0) has multiple resulting parameters with counts: {(4.0, 43.0): 1, (5.0, 43.0): 1}
# Combination (7.0, 56.0, 6.0) has multiple resulting parameters with counts: {(10.0, 58.0): 3, (10.0, 59.0): 1}
# Combination (7.0, 57.0, 5.0) has multiple resulting parameters with counts: {(11.0, 59.0): 47, (10.0, 59.0): 1, (10.0, 58.0): 1}
# Combination (7.0, 57.0, 6.0) has multiple resulting parameters with counts: {(11.0, 59.0): 1, (10.0, 59.0): 1}
# Combination (8.0, 42.0, 3.0) has multiple resulting parameters with counts: {(6.0, 43.0): 1, (5.0, 43.0): 1}
# Combination (8.0, 57.0, 3.0) has multiple resulting parameters with counts: {(11.0, 58.0): 3, (11.0, 59.0): 1}
# Combination (8.0, 58.0, 5.0) has multiple resulting parameters with counts: {(12.0, 60.0): 1, (11.0, 59.0): 1, (11.0, 60.0): 1}
# Combination (8.0, 58.0, 6.0) has multiple resulting parameters with counts: {(12.0, 60.0): 1, (11.0, 60.0): 1}
# Combination (9.0, 27.0, 1.0) has multiple resulting parameters with counts: {(1.0, 28.0): 1, (2.0, 28.0): 2}
# Combination (9.0, 35.0, 3.0) has multiple resulting parameters with counts: {(5.0, 37.0): 1, (4.0, 36.0): 3, (4.0, 37.0): 4}
# Combination (9.0, 40.0, 3.0) has multiple resulting parameters with counts: {(7.0, 42.0): 1, (6.0, 41.0): 1}
# Combination (9.0, 58.0, 5.0) has multiple resulting parameters with counts: {(12.0, 60.0): 1, (13.0, 60.0): 1}
# Combination (9.0, 58.0, 6.0) has multiple resulting parameters with counts: {(12.0, 60.0): 3, (13.0, 60.0): 2}
# Combination (10.0, 36.0, 3.0) has multiple resulting parameters with counts: {(6.0, 38.0): 1, (5.0, 37.0): 1}
# Combination (10.0, 38.0, 3.0) has multiple resulting parameters with counts: {(6.0, 39.0): 2, (7.0, 39.0): 1}
# Combination (10.0, 41.0, 3.0) has multiple resulting parameters with counts: {(7.0, 42.0): 1, (8.0, 42.0): 1}
# Combination (10.0, 48.0, 3.0) has multiple resulting parameters with counts: {(10.0, 50.0): 1, (10.0, 49.0): 1}
# Combination (10.0, 50.0, 5.0) has multiple resulting parameters with counts: {(11.0, 52.0): 2, (11.0, 51.0): 1}
# Combination (10.0, 58.0, 4.0) has multiple resulting parameters with counts: {(14.0, 59.0): 1, (13.0, 60.0): 2, (14.0, 60.0): 2, (13.0, 59.0): 1}
# Combination (10.0, 58.0, 6.0) has multiple resulting parameters with counts: {(14.0, 60.0): 6, (14.0, 61.0): 1}
# Combination (11.0, 28.0, 1.0) has multiple resulting parameters with counts: {(3.0, 29.0): 1, (4.0, 29.0): 3}
# Combination (11.0, 32.0, 3.0) has multiple resulting parameters with counts: {(5.0, 33.0): 3, (5.0, 34.0): 1}
# Combination (11.0, 46.0, 3.0) has multiple resulting parameters with counts: {(11.0, 47.0): 1, (10.0, 47.0): 1}
# Combination (11.0, 47.0, 3.0) has multiple resulting parameters with counts: {(11.0, 49.0): 1, (10.0, 48.0): 1}
# Combination (11.0, 58.0, 3.0) has multiple resulting parameters with counts: {(14.0, 60.0): 1, (14.0, 59.0): 1}
# Combination (11.0, 59.0, 3.0) has multiple resulting parameters with counts: {(15.0, 61.0): 1, (15.0, 60.0): 2, (14.0, 60.0): 1}
# Combination (11.0, 59.0, 6.0) has multiple resulting parameters with counts: {(15.0, 62.0): 1, (15.0, 61.0): 2, (16.0, 62.0): 1}
# Combination (11.0, 60.0, 5.0) has multiple resulting parameters with counts: {(15.0, 62.0): 1, (16.0, 62.0): 1}
# Combination (12.0, 18.0, 1.0) has multiple resulting parameters with counts: {(1.0, 18.0): 1, (1.0, 19.0): 1}
# Combination (12.0, 25.0, 1.0) has multiple resulting parameters with counts: {(4.0, 26.0): 2, (3.0, 25.0): 1, (3.0, 26.0): 1}
# Combination (12.0, 46.0, 3.0) has multiple resulting parameters with counts: {(11.0, 47.0): 1, (12.0, 47.0): 1}
# Combination (12.0, 52.0, 5.0) has multiple resulting parameters with counts: {(13.0, 53.0): 1, (14.0, 54.0): 1}
# Combination (12.0, 60.0, 3.0) has multiple resulting parameters with counts: {(17.0, 61.0): 1, (16.0, 61.0): 1}
# Combination (12.0, 60.0, 4.0) has multiple resulting parameters with counts: {(16.0, 61.0): 2, (16.0, 62.0): 1}
# Combination (13.0, 16.0, 1.0) has multiple resulting parameters with counts: {(1.0, 17.0): 1, (2.0, 17.0): 1}
# Combination (13.0, 19.0, 1.0) has multiple resulting parameters with counts: {(2.0, 20.0): 1, (3.0, 20.0): 1}
# Combination (13.0, 31.0, 1.0) has multiple resulting parameters with counts: {(6.0, 32.0): 1, (7.0, 32.0): 1}
# Combination (13.0, 45.0, 3.0) has multiple resulting parameters with counts: {(12.0, 46.0): 2, (11.0, 46.0): 1}
# Combination (13.0, 48.0, 3.0) has multiple resulting parameters with counts: {(12.0, 49.0): 1, (13.0, 49.0): 1}
# Combination (13.0, 59.0, 3.0) has multiple resulting parameters with counts: {(17.0, 60.0): 1, (17.0, 61.0): 1}
# Combination (13.0, 60.0, 5.0) has multiple resulting parameters with counts: {(17.0, 61.0): 1, (18.0, 62.0): 1, (17.0, 62.0): 1}
# Combination (14.0, 30.0, 3.0) has multiple resulting parameters with counts: {(7.0, 31.0): 3, (8.0, 31.0): 1}
# Combination (14.0, 34.0, 3.0) has multiple resulting parameters with counts: {(9.0, 35.0): 6, (9.0, 36.0): 1}
# Combination (14.0, 43.0, 5.0) has multiple resulting parameters with counts: {(12.0, 45.0): 1, (13.0, 45.0): 1}
# Combination (14.0, 60.0, 4.0) has multiple resulting parameters with counts: {(18.0, 61.0): 1, (18.0, 62.0): 3}
# Combination (14.0, 60.0, 5.0) has multiple resulting parameters with counts: {(19.0, 62.0): 1, (18.0, 62.0): 1}
# Combination (14.0, 61.0, 3.0) has multiple resulting parameters with counts: {(19.0, 62.0): 2, (18.0, 62.0): 1}
# Combination (15.0, 18.0, 1.0) has multiple resulting parameters with counts: {(4.0, 19.0): 2, (5.0, 19.0): 1}
# Combination (15.0, 25.0, 3.0) has multiple resulting parameters with counts: {(7.0, 26.0): 2, (7.0, 27.0): 1}
# Combination (15.0, 36.0, 3.0) has multiple resulting parameters with counts: {(11.0, 37.0): 1, (10.0, 37.0): 1}
# Combination (15.0, 54.0, 5.0) has multiple resulting parameters with counts: {(17.0, 56.0): 1, (18.0, 56.0): 1}
# Combination (15.0, 60.0, 3.0) has multiple resulting parameters with counts: {(19.0, 61.0): 2, (19.0, 62.0): 1}
# Combination (15.0, 60.0, 5.0) has multiple resulting parameters with counts: {(19.0, 62.0): 1, (20.0, 62.0): 1}
# Combination (15.0, 61.0, 5.0) has multiple resulting parameters with counts: {(19.0, 63.0): 45, (20.0, 63.0): 2}
# Combination (16.0, 25.0, 3.0) has multiple resulting parameters with counts: {(7.0, 26.0): 1, (8.0, 27.0): 1}
# Combination (16.0, 27.0, 3.0) has multiple resulting parameters with counts: {(9.0, 29.0): 1, (8.0, 28.0): 1}
# Combination (16.0, 32.0, 1.0) has multiple resulting parameters with counts: {(10.0, 33.0): 1, (11.0, 33.0): 1}
# Combination (16.0, 35.0, 4.0) has multiple resulting parameters with counts: {(12.0, 37.0): 1, (11.0, 36.0): 1}
# Combination (16.0, 38.0, 3.0) has multiple resulting parameters with counts: {(12.0, 39.0): 2, (13.0, 39.0): 1}
# Combination (16.0, 46.0, 3.0) has multiple resulting parameters with counts: {(15.0, 47.0): 1, (15.0, 48.0): 1}
# Combination (16.0, 52.0, 5.0) has multiple resulting parameters with counts: {(17.0, 54.0): 1, (18.0, 54.0): 1}
# Combination (16.0, 60.0, 4.0) has multiple resulting parameters with counts: {(20.0, 61.0): 1, (20.0, 62.0): 1}
# Combination (16.0, 61.0, 3.0) has multiple resulting parameters with counts: {(20.0, 63.0): 1, (21.0, 62.0): 1}
# Combination (17.0, 16.0, 1.0) has multiple resulting parameters with counts: {(6.0, 17.0): 2, (5.0, 17.0): 1}
# Combination (17.0, 26.0, 1.0) has multiple resulting parameters with counts: {(9.0, 27.0): 3, (9.0, 26.0): 1, (10.0, 27.0): 1}
# Combination (17.0, 31.0, 5.0) has multiple resulting parameters with counts: {(11.0, 32.0): 1, (11.0, 33.0): 1}
# Combination (17.0, 42.0, 3.0) has multiple resulting parameters with counts: {(15.0, 44.0): 1, (14.0, 43.0): 1}
# Combination (17.0, 61.0, 4.0) has multiple resulting parameters with counts: {(22.0, 63.0): 2, (22.0, 62.0): 1}
# Combination (17.0, 61.0, 5.0) has multiple resulting parameters with counts: {(22.0, 63.0): 2, (22.0, 62.0): 1}
# Combination (18.0, 27.0, 1.0) has multiple resulting parameters with counts: {(11.0, 28.0): 1, (10.0, 28.0): 3}
# Combination (18.0, 61.0, 4.0) has multiple resulting parameters with counts: {(23.0, 63.0): 1, (22.0, 63.0): 1}
# Combination (18.0, 62.0, 5.0) has multiple resulting parameters with counts: {(24.0, 64.0): 1, (23.0, 64.0): 2, (23.0, 63.0): 1}
# Combination (18.0, 62.0, 6.0) has multiple resulting parameters with counts: {(24.0, 65.0): 1, (24.0, 64.0): 2, (23.0, 64.0): 2}
# Combination (19.0, 10.0, 1.0) has multiple resulting parameters with counts: {(6.0, 11.0): 1, (5.0, 11.0): 1}
# Combination (19.0, 30.0, 3.0) has multiple resulting parameters with counts: {(13.0, 31.0): 1, (13.0, 32.0): 1}
# Combination (19.0, 32.0, 3.0) has multiple resulting parameters with counts: {(14.0, 34.0): 1, (14.0, 33.0): 1}
# Combination (19.0, 35.0, 3.0) has multiple resulting parameters with counts: {(14.0, 36.0): 1, (14.0, 37.0): 2}
# Combination (19.0, 41.0, 3.0) has multiple resulting parameters with counts: {(17.0, 42.0): 2, (16.0, 42.0): 1}
# Combination (19.0, 62.0, 3.0) has multiple resulting parameters with counts: {(24.0, 63.0): 2, (23.0, 63.0): 1}
# Combination (20.0, 28.0, 1.0) has multiple resulting parameters with counts: {(13.0, 29.0): 1, (12.0, 29.0): 1}
# Combination (20.0, 34.0, 3.0) has multiple resulting parameters with counts: {(15.0, 36.0): 2, (15.0, 35.0): 1, (14.0, 35.0): 1}
# Combination (20.0, 41.0, 3.0) has multiple resulting parameters with counts: {(18.0, 43.0): 2, (17.0, 43.0): 1}
# Combination (20.0, 48.0, 3.0) has multiple resulting parameters with counts: {(20.0, 50.0): 1, (20.0, 49.0): 1}
# Combination (20.0, 49.0, 2.0) has multiple resulting parameters with counts: {(21.0, 50.0): 1, (20.0, 50.0): 1}
# Combination (20.0, 52.0, 6.0) has multiple resulting parameters with counts: {(21.0, 54.0): 1, (22.0, 54.0): 1}
# Combination (20.0, 56.0, 5.0) has multiple resulting parameters with counts: {(22.0, 58.0): 1, (23.0, 58.0): 1}
# Combination (20.0, 62.0, 6.0) has multiple resulting parameters with counts: {(25.0, 64.0): 1, (25.0, 65.0): 1, (26.0, 64.0): 1}
# Combination (21.0, 34.0, 2.0) has multiple resulting parameters with counts: {(15.0, 35.0): 1, (16.0, 35.0): 1}
# Combination (21.0, 44.0, 5.0) has multiple resulting parameters with counts: {(20.0, 46.0): 1, (20.0, 45.0): 1}
# Combination (21.0, 46.0, 4.0) has multiple resulting parameters with counts: {(21.0, 47.0): 1, (20.0, 48.0): 2}
# Combination (21.0, 47.0, 2.0) has multiple resulting parameters with counts: {(20.0, 48.0): 2, (21.0, 48.0): 1}
# Combination (21.0, 59.0, 5.0) has multiple resulting parameters with counts: {(26.0, 61.0): 1, (25.0, 61.0): 1}
# Combination (21.0, 63.0, 5.0) has multiple resulting parameters with counts: {(26.0, 65.0): 1, (27.0, 65.0): 1}
# Combination (22.0, 40.0, 3.0) has multiple resulting parameters with counts: {(19.0, 41.0): 2, (20.0, 41.0): 1}
# Combination (22.0, 63.0, 3.0) has multiple resulting parameters with counts: {(28.0, 64.0): 1, (27.0, 64.0): 1}
# Combination (23.0, 31.0, 1.0) has multiple resulting parameters with counts: {(16.0, 32.0): 1, (17.0, 32.0): 1}
# Combination (23.0, 44.0, 2.0) has multiple resulting parameters with counts: {(21.0, 45.0): 1, (22.0, 45.0): 1}
# Combination (23.0, 63.0, 4.0) has multiple resulting parameters with counts: {(28.0, 64.0): 1, (28.0, 65.0): 1}
# Combination (23.0, 63.0, 6.0) has multiple resulting parameters with counts: {(28.0, 65.0): 1, (29.0, 65.0): 1}
# Combination (23.0, 64.0, 5.0) has multiple resulting parameters with counts: {(29.0, 66.0): 1, (28.0, 66.0): 1}
# Combination (24.0, 23.0, 3.0) has multiple resulting parameters with counts: {(16.0, 25.0): 1, (15.0, 25.0): 1}
# Combination (24.0, 24.0, 4.0) has multiple resulting parameters with counts: {(16.0, 26.0): 1, (15.0, 25.0): 1}
# Combination (24.0, 26.0, 3.0) has multiple resulting parameters with counts: {(17.0, 27.0): 1, (16.0, 28.0): 1, (16.0, 27.0): 1}
# Combination (24.0, 42.0, 4.0) has multiple resulting parameters with counts: {(21.0, 44.0): 1, (22.0, 43.0): 1}
# Combination (24.0, 43.0, 5.0) has multiple resulting parameters with counts: {(23.0, 45.0): 1, (22.0, 45.0): 1}
# Combination (24.0, 44.0, 3.0) has multiple resulting parameters with counts: {(23.0, 45.0): 1, (22.0, 45.0): 1}
# Combination (24.0, 63.0, 5.0) has multiple resulting parameters with counts: {(30.0, 65.0): 2, (29.0, 65.0): 1}
# Combination (24.0, 64.0, 4.0) has multiple resulting parameters with counts: {(29.0, 66.0): 1, (30.0, 65.0): 1, (30.0, 66.0): 1}
# Combination (25.0, 16.0, 1.0) has multiple resulting parameters with counts: {(13.0, 17.0): 1, (14.0, 17.0): 1}
# Combination (25.0, 32.0, 3.0) has multiple resulting parameters with counts: {(19.0, 33.0): 2, (20.0, 34.0): 2}
# Combination (25.0, 36.0, 3.0) has multiple resulting parameters with counts: {(20.0, 37.0): 1, (21.0, 37.0): 1}
# Combination (25.0, 47.0, 3.0) has multiple resulting parameters with counts: {(24.0, 48.0): 1, (25.0, 48.0): 1}
# Combination (25.0, 55.0, 5.0) has multiple resulting parameters with counts: {(27.0, 57.0): 1, (28.0, 57.0): 1}
# Combination (25.0, 56.0, 5.0) has multiple resulting parameters with counts: {(29.0, 58.0): 1, (28.0, 58.0): 1}
# Combination (25.0, 64.0, 3.0) has multiple resulting parameters with counts: {(30.0, 65.0): 1, (31.0, 65.0): 1}
# Combination (25.0, 65.0, 3.0) has multiple resulting parameters with counts: {(31.0, 67.0): 1, (31.0, 66.0): 1}
# Combination (26.0, 25.0, 1.0) has multiple resulting parameters with counts: {(17.0, 26.0): 3, (18.0, 26.0): 3}
# Combination (26.0, 26.0, 1.0) has multiple resulting parameters with counts: {(18.0, 27.0): 4, (19.0, 27.0): 1}
# Combination (26.0, 38.0, 3.0) has multiple resulting parameters with counts: {(22.0, 40.0): 1, (22.0, 39.0): 1}
# Combination (26.0, 39.0, 3.0) has multiple resulting parameters with counts: {(23.0, 40.0): 2, (22.0, 40.0): 1}
# Combination (26.0, 48.0, 3.0) has multiple resulting parameters with counts: {(26.0, 50.0): 1, (26.0, 49.0): 1}
# Combination (27.0, 29.0, 1.0) has multiple resulting parameters with counts: {(21.0, 30.0): 1, (20.0, 30.0): 1}
# Combination (27.0, 42.0, 2.0) has multiple resulting parameters with counts: {(24.0, 43.0): 1, (25.0, 43.0): 1}
# Combination (27.0, 46.0, 3.0) has multiple resulting parameters with counts: {(27.0, 47.0): 1, (26.0, 47.0): 1}
# Combination (27.0, 64.0, 3.0) has multiple resulting parameters with counts: {(33.0, 65.0): 1, (33.0, 66.0): 1, (32.0, 65.0): 1}
# Combination (28.0, 19.0, 1.0) has multiple resulting parameters with counts: {(17.0, 20.0): 2, (18.0, 20.0): 2}
# Combination (28.0, 27.0, 1.0) has multiple resulting parameters with counts: {(21.0, 28.0): 1, (20.0, 28.0): 1}
# Combination (28.0, 27.0, 3.0) has multiple resulting parameters with counts: {(21.0, 29.0): 2, (21.0, 28.0): 1}
# Combination (28.0, 50.0, 6.0) has multiple resulting parameters with counts: {(29.0, 53.0): 1, (30.0, 53.0): 1}
# Combination (29.0, 23.0, 1.0) has multiple resulting parameters with counts: {(20.0, 24.0): 2, (21.0, 24.0): 1}
# Combination (29.0, 30.0, 1.0) has multiple resulting parameters with counts: {(22.0, 31.0): 1, (23.0, 31.0): 2}
# Combination (29.0, 40.0, 4.0) has multiple resulting parameters with counts: {(27.0, 42.0): 1, (26.0, 41.0): 1}
# Combination (29.0, 65.0, 3.0) has multiple resulting parameters with counts: {(35.0, 67.0): 1, (35.0, 66.0): 1}
# Combination (29.0, 65.0, 5.0) has multiple resulting parameters with counts: {(35.0, 67.0): 2, (36.0, 67.0): 1}
# Combination (29.0, 66.0, 6.0) has multiple resulting parameters with counts: {(35.0, 69.0): 1, (36.0, 68.0): 1}
# Combination (30.0, 34.0, 3.0) has multiple resulting parameters with counts: {(25.0, 35.0): 1, (24.0, 35.0): 1, (25.0, 36.0): 2}
# Combination (30.0, 37.0, 3.0) has multiple resulting parameters with counts: {(26.0, 39.0): 3, (26.0, 38.0): 1}
# Combination (30.0, 44.0, 3.0) has multiple resulting parameters with counts: {(29.0, 46.0): 1, (29.0, 45.0): 1}
# Combination (30.0, 63.0, 5.0) has multiple resulting parameters with counts: {(35.0, 65.0): 1, (36.0, 66.0): 1}
# Combination (30.0, 66.0, 3.0) has multiple resulting parameters with counts: {(36.0, 67.0): 1, (37.0, 68.0): 1}
# Combination (31.0, 28.0, 3.0) has multiple resulting parameters with counts: {(24.0, 29.0): 2, (24.0, 30.0): 1}
# Combination (31.0, 32.0, 3.0) has multiple resulting parameters with counts: {(26.0, 33.0): 1, (25.0, 33.0): 2}
# Combination (31.0, 43.0, 3.0) has multiple resulting parameters with counts: {(29.0, 44.0): 1, (30.0, 44.0): 1}
# Combination (31.0, 65.0, 3.0) has multiple resulting parameters with counts: {(37.0, 66.0): 1, (37.0, 67.0): 1}
# Combination (32.0, 26.0, 3.0) has multiple resulting parameters with counts: {(25.0, 27.0): 1, (24.0, 27.0): 1}
# Combination (32.0, 29.0, 3.0) has multiple resulting parameters with counts: {(26.0, 31.0): 2, (25.0, 30.0): 1}
# Combination (32.0, 30.0, 3.0) has multiple resulting parameters with counts: {(25.0, 32.0): 2, (25.0, 31.0): 4}
# Combination (33.0, 41.0, 3.0) has multiple resulting parameters with counts: {(31.0, 43.0): 1, (31.0, 42.0): 1}
# Combination (33.0, 67.0, 4.0) has multiple resulting parameters with counts: {(39.0, 69.0): 2, (40.0, 69.0): 1}
# Combination (34.0, 18.0, 1.0) has multiple resulting parameters with counts: {(23.0, 19.0): 1, (24.0, 19.0): 1}
# Combination (34.0, 24.0, 1.0) has multiple resulting parameters with counts: {(25.0, 25.0): 1, (26.0, 25.0): 6}
# Combination (34.0, 27.0, 3.0) has multiple resulting parameters with counts: {(27.0, 28.0): 1, (26.0, 29.0): 1}
# Combination (34.0, 46.0, 5.0) has multiple resulting parameters with counts: {(33.0, 48.0): 1, (34.0, 48.0): 1}
# Combination (34.0, 57.0, 6.0) has multiple resulting parameters with counts: {(38.0, 60.0): 1, (37.0, 59.0): 1}
# Combination (34.0, 67.0, 6.0) has multiple resulting parameters with counts: {(41.0, 70.0): 1, (41.0, 69.0): 2}
# Combination (35.0, 25.0, 1.0) has multiple resulting parameters with counts: {(26.0, 26.0): 5, (27.0, 26.0): 2}
# Combination (35.0, 29.0, 1.0) has multiple resulting parameters with counts: {(29.0, 30.0): 1, (28.0, 30.0): 1}
# Combination (35.0, 31.0, 3.0) has multiple resulting parameters with counts: {(29.0, 32.0): 1, (29.0, 33.0): 2}
# Combination (35.0, 37.0, 3.0) has multiple resulting parameters with counts: {(31.0, 38.0): 1, (31.0, 39.0): 1}
# Combination (35.0, 38.0, 3.0) has multiple resulting parameters with counts: {(32.0, 40.0): 1, (31.0, 40.0): 1}
# Combination (35.0, 48.0, 3.0) has multiple resulting parameters with counts: {(35.0, 49.0): 1, (35.0, 50.0): 1}
# Combination (35.0, 67.0, 3.0) has multiple resulting parameters with counts: {(41.0, 69.0): 1, (42.0, 68.0): 1}
# Combination (36.0, 15.0, 1.0) has multiple resulting parameters with counts: {(24.0, 16.0): 2, (25.0, 16.0): 1}
# Combination (36.0, 24.0, 3.0) has multiple resulting parameters with counts: {(27.0, 25.0): 1, (27.0, 26.0): 1}
# Combination (36.0, 67.0, 3.0) has multiple resulting parameters with counts: {(42.0, 68.0): 1, (43.0, 69.0): 2, (43.0, 68.0): 1}
# Combination (36.0, 68.0, 5.0) has multiple resulting parameters with counts: {(44.0, 70.0): 1, (43.0, 70.0): 1}
# Combination (37.0, 47.0, 3.0) has multiple resulting parameters with counts: {(36.0, 49.0): 1, (37.0, 49.0): 1}
# Combination (37.0, 49.0, 3.0) has multiple resulting parameters with counts: {(38.0, 50.0): 1, (37.0, 50.0): 2}
# Combination (37.0, 59.0, 6.0) has multiple resulting parameters with counts: {(41.0, 62.0): 1, (42.0, 61.0): 1}
# Combination (38.0, 18.0, 1.0) has multiple resulting parameters with counts: {(28.0, 19.0): 2, (27.0, 19.0): 1, (27.0, 20.0): 1}
# Combination (38.0, 27.0, 3.0) has multiple resulting parameters with counts: {(31.0, 28.0): 3, (30.0, 28.0): 1}
# Combination (38.0, 29.0, 3.0) has multiple resulting parameters with counts: {(31.0, 31.0): 2, (32.0, 30.0): 5}
# Combination (38.0, 30.0, 1.0) has multiple resulting parameters with counts: {(31.0, 31.0): 1, (32.0, 31.0): 1}
# Combination (38.0, 44.0, 3.0) has multiple resulting parameters with counts: {(37.0, 45.0): 1, (36.0, 46.0): 1}
# Combination (38.0, 46.0, 3.0) has multiple resulting parameters with counts: {(37.0, 48.0): 1, (37.0, 47.0): 2}
# Combination (38.0, 52.0, 5.0) has multiple resulting parameters with counts: {(39.0, 54.0): 1, (40.0, 55.0): 1}
# Combination (39.0, 21.0, 1.0) has multiple resulting parameters with counts: {(29.0, 22.0): 1, (30.0, 22.0): 1}
# Combination (39.0, 28.0, 3.0) has multiple resulting parameters with counts: {(32.0, 29.0): 2, (32.0, 30.0): 1}
# Combination (39.0, 30.0, 3.0) has multiple resulting parameters with counts: {(33.0, 31.0): 1, (32.0, 32.0): 1}
# Combination (39.0, 34.0, 3.0) has multiple resulting parameters with counts: {(34.0, 36.0): 4, (34.0, 35.0): 1}
# Combination (39.0, 38.0, 3.0) has multiple resulting parameters with counts: {(36.0, 40.0): 1, (35.0, 39.0): 1}
# Combination (39.0, 46.0, 3.0) has multiple resulting parameters with counts: {(39.0, 48.0): 1, (38.0, 48.0): 1}
# Combination (39.0, 53.0, 5.0) has multiple resulting parameters with counts: {(40.0, 55.0): 1, (41.0, 55.0): 1}
# Combination (39.0, 59.0, 4.0) has multiple resulting parameters with counts: {(43.0, 61.0): 1, (43.0, 60.0): 1}
# Combination (39.0, 66.0, 5.0) has multiple resulting parameters with counts: {(45.0, 68.0): 1, (46.0, 68.0): 1}
# Combination (40.0, 58.0, 5.0) has multiple resulting parameters with counts: {(43.0, 60.0): 1, (44.0, 61.0): 1}
# Combination (41.0, 13.0, 1.0) has multiple resulting parameters with counts: {(29.0, 14.0): 1, (28.0, 14.0): 1}
# Combination (41.0, 23.0, 3.0) has multiple resulting parameters with counts: {(33.0, 25.0): 1, (32.0, 25.0): 2}
# Combination (41.0, 27.0, 1.0) has multiple resulting parameters with counts: {(33.0, 28.0): 1, (34.0, 28.0): 1}
# Combination (41.0, 31.0, 3.0) has multiple resulting parameters with counts: {(35.0, 32.0): 2, (35.0, 33.0): 2}
# Combination (41.0, 43.0, 3.0) has multiple resulting parameters with counts: {(39.0, 45.0): 2, (40.0, 45.0): 1, (39.0, 44.0): 1}
# Combination (41.0, 45.0, 3.0) has multiple resulting parameters with counts: {(40.0, 47.0): 1, (40.0, 46.0): 1}
# Combination (41.0, 55.0, 5.0) has multiple resulting parameters with counts: {(44.0, 57.0): 1, (43.0, 57.0): 1}
# Combination (41.0, 66.0, 5.0) has multiple resulting parameters with counts: {(47.0, 68.0): 1, (48.0, 68.0): 1}
# Combination (41.0, 69.0, 5.0) has multiple resulting parameters with counts: {(49.0, 71.0): 1, (49.0, 72.0): 1}
# Combination (42.0, 27.0, 1.0) has multiple resulting parameters with counts: {(34.0, 28.0): 1, (35.0, 29.0): 1}
# Combination (42.0, 45.0, 3.0) has multiple resulting parameters with counts: {(42.0, 47.0): 1, (41.0, 47.0): 1}
# Combination (42.0, 47.0, 3.0) has multiple resulting parameters with counts: {(41.0, 48.0): 1, (42.0, 49.0): 1}
# Combination (42.0, 49.0, 3.0) has multiple resulting parameters with counts: {(43.0, 51.0): 1, (42.0, 50.0): 1, (43.0, 50.0): 1}
# Combination (42.0, 52.0, 5.0) has multiple resulting parameters with counts: {(44.0, 54.0): 1, (43.0, 54.0): 1}
# Combination (42.0, 64.0, 5.0) has multiple resulting parameters with counts: {(47.0, 66.0): 1, (48.0, 66.0): 1}
# Combination (43.0, 20.0, 3.0) has multiple resulting parameters with counts: {(34.0, 22.0): 1, (33.0, 22.0): 1}
# Combination (43.0, 22.0, 1.0) has multiple resulting parameters with counts: {(34.0, 24.0): 1, (34.0, 23.0): 1}
# Combination (43.0, 23.0, 1.0) has multiple resulting parameters with counts: {(35.0, 25.0): 4, (34.0, 24.0): 6}
# Combination (43.0, 28.0, 1.0) has multiple resulting parameters with counts: {(35.0, 29.0): 1, (36.0, 29.0): 2}
# Combination (43.0, 41.0, 3.0) has multiple resulting parameters with counts: {(40.0, 42.0): 1, (41.0, 43.0): 1}
# Combination (43.0, 46.0, 4.0) has multiple resulting parameters with counts: {(43.0, 48.0): 1, (43.0, 47.0): 1}
# Combination (43.0, 47.0, 3.0) has multiple resulting parameters with counts: {(43.0, 49.0): 1, (42.0, 49.0): 1}
# Combination (43.0, 64.0, 3.0) has multiple resulting parameters with counts: {(49.0, 65.0): 1, (49.0, 66.0): 1}
# Combination (43.0, 69.0, 5.0) has multiple resulting parameters with counts: {(51.0, 71.0): 2, (50.0, 71.0): 1}
# Combination (43.0, 69.0, 6.0) has multiple resulting parameters with counts: {(50.0, 72.0): 1, (50.0, 71.0): 2}
# Combination (44.0, 44.0, 3.0) has multiple resulting parameters with counts: {(42.0, 45.0): 2, (43.0, 46.0): 1}
# Combination (44.0, 46.0, 3.0) has multiple resulting parameters with counts: {(44.0, 47.0): 2, (43.0, 48.0): 1, (43.0, 47.0): 1}
# Combination (44.0, 53.0, 4.0) has multiple resulting parameters with counts: {(46.0, 55.0): 1, (46.0, 54.0): 1}
# Combination (44.0, 70.0, 3.0) has multiple resulting parameters with counts: {(52.0, 71.0): 1, (51.0, 72.0): 1}
# Combination (45.0, 28.0, 3.0) has multiple resulting parameters with counts: {(38.0, 30.0): 2, (38.0, 29.0): 1}
# Combination (46.0, 21.0, 4.0) has multiple resulting parameters with counts: {(36.0, 23.0): 1, (37.0, 23.0): 1}
# Combination (46.0, 27.0, 3.0) has multiple resulting parameters with counts: {(38.0, 29.0): 5, (39.0, 28.0): 1}
# Combination (46.0, 40.0, 3.0) has multiple resulting parameters with counts: {(43.0, 42.0): 3, (44.0, 42.0): 1, (43.0, 41.0): 1}
# Combination (46.0, 55.0, 5.0) has multiple resulting parameters with counts: {(49.0, 57.0): 1, (48.0, 57.0): 1}
# Combination (47.0, 24.0, 2.0) has multiple resulting parameters with counts: {(38.0, 25.0): 1, (39.0, 25.0): 1}
# Combination (47.0, 43.0, 3.0) has multiple resulting parameters with counts: {(46.0, 44.0): 2, (45.0, 44.0): 1}
# Combination (47.0, 70.0, 3.0) has multiple resulting parameters with counts: {(55.0, 72.0): 1, (54.0, 71.0): 1}
# Combination (48.0, 52.0, 6.0) has multiple resulting parameters with counts: {(50.0, 55.0): 1, (50.0, 54.0): 1}
# Combination (48.0, 56.0, 3.0) has multiple resulting parameters with counts: {(51.0, 58.0): 1, (50.0, 57.0): 1}
# Combination (48.0, 72.0, 4.0) has multiple resulting parameters with counts: {(57.0, 73.0): 1, (57.0, 74.0): 1}
# Combination (49.0, 17.0, 1.0) has multiple resulting parameters with counts: {(38.0, 18.0): 4, (38.0, 19.0): 1}
# Combination (49.0, 20.0, 1.0) has multiple resulting parameters with counts: {(39.0, 21.0): 2, (39.0, 22.0): 1}
# Combination (49.0, 28.0, 3.0) has multiple resulting parameters with counts: {(42.0, 29.0): 1, (42.0, 30.0): 2}
# Combination (49.0, 38.0, 3.0) has multiple resulting parameters with counts: {(45.0, 40.0): 1, (46.0, 40.0): 1}
# Combination (49.0, 41.0, 3.0) has multiple resulting parameters with counts: {(46.0, 42.0): 1, (47.0, 43.0): 1, (46.0, 43.0): 1}
# Combination (49.0, 57.0, 5.0) has multiple resulting parameters with counts: {(53.0, 59.0): 2, (52.0, 59.0): 1}
# Combination (49.0, 58.0, 5.0) has multiple resulting parameters with counts: {(53.0, 61.0): 1, (53.0, 60.0): 1}
# Combination (49.0, 72.0, 4.0) has multiple resulting parameters with counts: {(58.0, 74.0): 1, (57.0, 73.0): 1}
# Combination (50.0, 26.0, 1.0) has multiple resulting parameters with counts: {(43.0, 28.0): 1, (42.0, 27.0): 2}
# Combination (50.0, 39.0, 3.0) has multiple resulting parameters with counts: {(47.0, 41.0): 1, (47.0, 40.0): 1, (46.0, 40.0): 1}
# Combination (50.0, 44.0, 3.0) has multiple resulting parameters with counts: {(49.0, 46.0): 1, (48.0, 45.0): 1}
# Combination (50.0, 71.0, 3.0) has multiple resulting parameters with counts: {(58.0, 72.0): 2, (58.0, 73.0): 2}
# Combination (50.0, 71.0, 4.0) has multiple resulting parameters with counts: {(58.0, 73.0): 1, (59.0, 73.0): 1}
# Combination (50.0, 71.0, 5.0) has multiple resulting parameters with counts: {(59.0, 74.0): 1, (59.0, 73.0): 1}
# Combination (50.0, 72.0, 5.0) has multiple resulting parameters with counts: {(58.0, 74.0): 1, (59.0, 74.0): 1}
# Combination (51.0, 18.0, 3.0) has multiple resulting parameters with counts: {(40.0, 20.0): 1, (40.0, 19.0): 1}
# Combination (51.0, 24.0, 3.0) has multiple resulting parameters with counts: {(42.0, 25.0): 1, (43.0, 26.0): 1}
# Combination (51.0, 27.0, 1.0) has multiple resulting parameters with counts: {(44.0, 28.0): 1, (43.0, 28.0): 2}
# Combination (51.0, 27.0, 3.0) has multiple resulting parameters with counts: {(44.0, 29.0): 1, (43.0, 28.0): 1}
# Combination (51.0, 61.0, 5.0) has multiple resulting parameters with counts: {(56.0, 63.0): 1, (56.0, 64.0): 1}
# Combination (52.0, 27.0, 3.0) has multiple resulting parameters with counts: {(45.0, 28.0): 1, (44.0, 29.0): 1}
# Combination (52.0, 40.0, 3.0) has multiple resulting parameters with counts: {(49.0, 41.0): 2, (50.0, 41.0): 2}
# Combination (52.0, 47.0, 4.0) has multiple resulting parameters with counts: {(51.0, 49.0): 1, (52.0, 49.0): 1}
# Combination (52.0, 49.0, 4.0) has multiple resulting parameters with counts: {(52.0, 51.0): 1, (52.0, 50.0): 1}
# Combination (53.0, 12.0, 1.0) has multiple resulting parameters with counts: {(41.0, 13.0): 1, (40.0, 13.0): 1}
# Combination (53.0, 13.0, 1.0) has multiple resulting parameters with counts: {(40.0, 14.0): 2, (41.0, 14.0): 1}
# Combination (53.0, 19.0, 4.0) has multiple resulting parameters with counts: {(42.0, 21.0): 1, (43.0, 21.0): 2}
# Combination (53.0, 21.0, 1.0) has multiple resulting parameters with counts: {(43.0, 22.0): 2, (43.0, 23.0): 2}
# Combination (53.0, 22.0, 1.0) has multiple resulting parameters with counts: {(43.0, 23.0): 8, (43.0, 24.0): 1}
# Combination (53.0, 23.0, 1.0) has multiple resulting parameters with counts: {(43.0, 24.0): 2, (44.0, 24.0): 1}
# Combination (53.0, 23.0, 3.0) has multiple resulting parameters with counts: {(44.0, 25.0): 1, (44.0, 24.0): 1}
# Combination (53.0, 34.0, 4.0) has multiple resulting parameters with counts: {(49.0, 36.0): 1, (49.0, 35.0): 1}
# Combination (53.0, 36.0, 3.0) has multiple resulting parameters with counts: {(48.0, 38.0): 1, (49.0, 37.0): 1}
# Combination (53.0, 37.0, 3.0) has multiple resulting parameters with counts: {(49.0, 38.0): 2, (49.0, 39.0): 2, (50.0, 39.0): 1}
# Combination (53.0, 40.0, 3.0) has multiple resulting parameters with counts: {(50.0, 41.0): 1, (50.0, 42.0): 1}
# Combination (53.0, 52.0, 3.0) has multiple resulting parameters with counts: {(54.0, 54.0): 1, (55.0, 53.0): 1}
# Combination (53.0, 55.0, 4.0) has multiple resulting parameters with counts: {(55.0, 57.0): 1, (56.0, 56.0): 1}
# Combination (53.0, 61.0, 5.0) has multiple resulting parameters with counts: {(58.0, 64.0): 2, (58.0, 63.0): 1}
# Combination (54.0, 19.0, 3.0) has multiple resulting parameters with counts: {(43.0, 20.0): 2, (44.0, 21.0): 1}
# Combination (54.0, 36.0, 3.0) has multiple resulting parameters with counts: {(50.0, 38.0): 1, (49.0, 38.0): 1}
# Combination (54.0, 41.0, 3.0) has multiple resulting parameters with counts: {(52.0, 42.0): 1, (52.0, 43.0): 1}
# Combination (54.0, 53.0, 6.0) has multiple resulting parameters with counts: {(56.0, 55.0): 1, (56.0, 56.0): 1}
# Combination (54.0, 63.0, 5.0) has multiple resulting parameters with counts: {(60.0, 66.0): 1, (59.0, 65.0): 1}
# Combination (55.0, 16.0, 3.0) has multiple resulting parameters with counts: {(44.0, 18.0): 1, (43.0, 18.0): 1}
# Combination (55.0, 24.0, 3.0) has multiple resulting parameters with counts: {(47.0, 25.0): 1, (46.0, 25.0): 2}
# Combination (55.0, 28.0, 3.0) has multiple resulting parameters with counts: {(48.0, 29.0): 2, (48.0, 30.0): 1}
# Combination (55.0, 38.0, 3.0) has multiple resulting parameters with counts: {(51.0, 39.0): 2, (52.0, 40.0): 1}
# Combination (55.0, 43.0, 4.0) has multiple resulting parameters with counts: {(53.0, 45.0): 3, (54.0, 45.0): 1}
# Combination (55.0, 63.0, 5.0) has multiple resulting parameters with counts: {(61.0, 65.0): 1, (60.0, 65.0): 2}
# Combination (55.0, 67.0, 3.0) has multiple resulting parameters with counts: {(62.0, 68.0): 1, (62.0, 69.0): 1}
# Combination (55.0, 72.0, 3.0) has multiple resulting parameters with counts: {(64.0, 74.0): 1, (63.0, 74.0): 2}
# Combination (55.0, 72.0, 6.0) has multiple resulting parameters with counts: {(64.0, 75.0): 1, (63.0, 74.0): 1}
# Combination (56.0, 36.0, 3.0) has multiple resulting parameters with counts: {(52.0, 38.0): 1, (52.0, 37.0): 1}
# Combination (56.0, 38.0, 3.0) has multiple resulting parameters with counts: {(53.0, 40.0): 1, (52.0, 40.0): 2}
# Combination (56.0, 38.0, 5.0) has multiple resulting parameters with counts: {(53.0, 40.0): 1, (52.0, 40.0): 1}
# Combination (57.0, 22.0, 5.0) has multiple resulting parameters with counts: {(48.0, 25.0): 1, (48.0, 24.0): 1}
# Combination (57.0, 30.0, 3.0) has multiple resulting parameters with counts: {(50.0, 31.0): 4, (51.0, 32.0): 1}
# Combination (57.0, 39.0, 3.0) has multiple resulting parameters with counts: {(54.0, 40.0): 1, (54.0, 41.0): 1}
# Combination (57.0, 40.0, 2.0) has multiple resulting parameters with counts: {(55.0, 41.0): 1, (54.0, 41.0): 1}
# Combination (57.0, 41.0, 4.0) has multiple resulting parameters with counts: {(54.0, 43.0): 1, (55.0, 43.0): 1}
# Combination (57.0, 47.0, 4.0) has multiple resulting parameters with counts: {(57.0, 49.0): 1, (56.0, 49.0): 1}
# Combination (57.0, 56.0, 5.0) has multiple resulting parameters with counts: {(61.0, 58.0): 1, (60.0, 58.0): 1}
# Combination (57.0, 57.0, 4.0) has multiple resulting parameters with counts: {(60.0, 58.0): 1, (61.0, 59.0): 1}
# Combination (57.0, 61.0, 5.0) has multiple resulting parameters with counts: {(62.0, 63.0): 1, (61.0, 63.0): 1}
# Combination (57.0, 71.0, 5.0) has multiple resulting parameters with counts: {(65.0, 73.0): 1, (66.0, 74.0): 1}
# Combination (57.0, 72.0, 3.0) has multiple resulting parameters with counts: {(66.0, 73.0): 1, (66.0, 74.0): 1}
# Combination (57.0, 73.0, 4.0) has multiple resulting parameters with counts: {(66.0, 75.0): 1, (67.0, 75.0): 1}
# Combination (57.0, 74.0, 3.0) has multiple resulting parameters with counts: {(66.0, 75.0): 1, (66.0, 76.0): 1}
# Combination (58.0, 24.0, 1.0) has multiple resulting parameters with counts: {(49.0, 25.0): 1, (49.0, 26.0): 1}
# Combination (58.0, 34.0, 3.0) has multiple resulting parameters with counts: {(53.0, 35.0): 1, (53.0, 36.0): 1}
# Combination (58.0, 36.0, 3.0) has multiple resulting parameters with counts: {(54.0, 37.0): 2, (53.0, 37.0): 2}
# Combination (58.0, 72.0, 3.0) has multiple resulting parameters with counts: {(67.0, 74.0): 1, (66.0, 73.0): 1}
# Combination (58.0, 72.0, 4.0) has multiple resulting parameters with counts: {(66.0, 74.0): 1, (67.0, 74.0): 1}
# Combination (59.0, 19.0, 1.0) has multiple resulting parameters with counts: {(49.0, 21.0): 1, (49.0, 20.0): 2}
# Combination (59.0, 19.0, 4.0) has multiple resulting parameters with counts: {(48.0, 21.0): 1, (49.0, 21.0): 1}
# Combination (59.0, 25.0, 1.0) has multiple resulting parameters with counts: {(50.0, 26.0): 1, (51.0, 27.0): 2}
# Combination (59.0, 40.0, 3.0) has multiple resulting parameters with counts: {(56.0, 41.0): 1, (57.0, 42.0): 1}
# Combination (59.0, 74.0, 4.0) has multiple resulting parameters with counts: {(68.0, 76.0): 1, (68.0, 75.0): 1}
# Combination (59.0, 74.0, 6.0) has multiple resulting parameters with counts: {(69.0, 76.0): 1, (68.0, 77.0): 1}
# Combination (60.0, 16.0, 1.0) has multiple resulting parameters with counts: {(49.0, 17.0): 3, (48.0, 17.0): 1}
# Combination (60.0, 20.0, 3.0) has multiple resulting parameters with counts: {(51.0, 22.0): 1, (50.0, 22.0): 2}
# Combination (60.0, 26.0, 1.0) has multiple resulting parameters with counts: {(52.0, 27.0): 1, (52.0, 28.0): 1}
# Combination (60.0, 31.0, 3.0) has multiple resulting parameters with counts: {(54.0, 32.0): 2, (55.0, 33.0): 1}
# Combination (60.0, 37.0, 3.0) has multiple resulting parameters with counts: {(56.0, 38.0): 4, (56.0, 39.0): 1}
# Combination (60.0, 40.0, 2.0) has multiple resulting parameters with counts: {(57.0, 41.0): 1, (58.0, 42.0): 1}
# Combination (60.0, 40.0, 3.0) has multiple resulting parameters with counts: {(57.0, 41.0): 1, (57.0, 42.0): 1}
# Combination (60.0, 58.0, 3.0) has multiple resulting parameters with counts: {(64.0, 60.0): 1, (63.0, 59.0): 1}
# Combination (60.0, 67.0, 5.0) has multiple resulting parameters with counts: {(67.0, 69.0): 1, (67.0, 70.0): 1}
# Combination (60.0, 69.0, 4.0) has multiple resulting parameters with counts: {(68.0, 70.0): 1, (68.0, 71.0): 1}
# Combination (60.0, 73.0, 3.0) has multiple resulting parameters with counts: {(69.0, 74.0): 1, (68.0, 74.0): 1}
# Combination (61.0, 16.0, 1.0) has multiple resulting parameters with counts: {(49.0, 17.0): 2, (50.0, 17.0): 1}
# Combination (61.0, 39.0, 2.0) has multiple resulting parameters with counts: {(57.0, 40.0): 1, (58.0, 40.0): 1}
# Combination (61.0, 45.0, 4.0) has multiple resulting parameters with counts: {(60.0, 47.0): 1, (60.0, 46.0): 1}
# Combination (61.0, 63.0, 5.0) has multiple resulting parameters with counts: {(66.0, 65.0): 1, (67.0, 65.0): 2}
# Combination (61.0, 65.0, 5.0) has multiple resulting parameters with counts: {(67.0, 67.0): 1, (68.0, 68.0): 1}
# Combination (62.0, 15.0, 1.0) has multiple resulting parameters with counts: {(50.0, 16.0): 1, (50.0, 17.0): 1}
# Combination (62.0, 21.0, 1.0) has multiple resulting parameters with counts: {(53.0, 22.0): 7, (53.0, 23.0): 2}
# Combination (62.0, 22.0, 1.0) has multiple resulting parameters with counts: {(53.0, 24.0): 1, (53.0, 23.0): 1}
# Combination (62.0, 23.0, 1.0) has multiple resulting parameters with counts: {(53.0, 25.0): 1, (53.0, 24.0): 1}
# Combination (62.0, 24.0, 3.0) has multiple resulting parameters with counts: {(54.0, 26.0): 4, (53.0, 26.0): 1}
# Combination (62.0, 27.0, 3.0) has multiple resulting parameters with counts: {(55.0, 28.0): 1, (54.0, 28.0): 1}
# Combination (62.0, 28.0, 4.0) has multiple resulting parameters with counts: {(55.0, 30.0): 1, (56.0, 30.0): 1}
# Combination (62.0, 33.0, 3.0) has multiple resulting parameters with counts: {(56.0, 34.0): 1, (57.0, 35.0): 1}
# Combination (62.0, 74.0, 3.0) has multiple resulting parameters with counts: {(71.0, 75.0): 1, (71.0, 76.0): 1}
# Combination (63.0, 34.0, 3.0) has multiple resulting parameters with counts: {(58.0, 36.0): 4, (58.0, 35.0): 2}
# Combination (63.0, 51.0, 3.0) has multiple resulting parameters with counts: {(65.0, 53.0): 1, (64.0, 52.0): 1}
# Combination (63.0, 60.0, 5.0) has multiple resulting parameters with counts: {(68.0, 62.0): 1, (67.0, 63.0): 1}
# Combination (63.0, 65.0, 5.0) has multiple resulting parameters with counts: {(70.0, 67.0): 1, (69.0, 67.0): 1}
# Combination (63.0, 74.0, 6.0) has multiple resulting parameters with counts: {(73.0, 76.0): 1, (73.0, 77.0): 1}
# Combination (64.0, 16.0, 3.0) has multiple resulting parameters with counts: {(53.0, 17.0): 1, (53.0, 18.0): 1}
# Combination (64.0, 28.0, 3.0) has multiple resulting parameters with counts: {(57.0, 30.0): 4, (57.0, 29.0): 1}
# Combination (64.0, 33.0, 3.0) has multiple resulting parameters with counts: {(59.0, 35.0): 1, (58.0, 34.0): 1}
# Combination (64.0, 35.0, 3.0) has multiple resulting parameters with counts: {(60.0, 37.0): 3, (59.0, 36.0): 3, (60.0, 36.0): 1}
# Combination (64.0, 60.0, 3.0) has multiple resulting parameters with counts: {(68.0, 62.0): 1, (69.0, 62.0): 1}
# Combination (64.0, 66.0, 5.0) has multiple resulting parameters with counts: {(71.0, 68.0): 1, (70.0, 68.0): 1}
# Combination (65.0, 28.0, 4.0) has multiple resulting parameters with counts: {(58.0, 29.0): 1, (58.0, 30.0): 1}
# Combination (65.0, 36.0, 4.0) has multiple resulting parameters with counts: {(60.0, 38.0): 1, (61.0, 38.0): 1}
# Combination (65.0, 40.0, 5.0) has multiple resulting parameters with counts: {(63.0, 43.0): 1, (63.0, 42.0): 1}
# Combination (65.0, 45.0, 4.0) has multiple resulting parameters with counts: {(65.0, 47.0): 1, (64.0, 47.0): 1}
# Combination (65.0, 52.0, 5.0) has multiple resulting parameters with counts: {(67.0, 55.0): 1, (66.0, 54.0): 1}
# Combination (66.0, 11.0, 1.0) has multiple resulting parameters with counts: {(53.0, 13.0): 3, (53.0, 12.0): 1}
# Combination (66.0, 48.0, 3.0) has multiple resulting parameters with counts: {(67.0, 50.0): 1, (66.0, 50.0): 1}
# Combination (66.0, 65.0, 5.0) has multiple resulting parameters with counts: {(73.0, 68.0): 1, (72.0, 67.0): 1}
# Combination (67.0, 23.0, 1.0) has multiple resulting parameters with counts: {(58.0, 24.0): 2, (58.0, 25.0): 1}
# Combination (67.0, 24.0, 1.0) has multiple resulting parameters with counts: {(59.0, 25.0): 3, (58.0, 25.0): 1}
# Combination (67.0, 37.0, 2.0) has multiple resulting parameters with counts: {(64.0, 39.0): 1, (63.0, 38.0): 1}
# Combination (67.0, 37.0, 3.0) has multiple resulting parameters with counts: {(63.0, 39.0): 1, (63.0, 38.0): 1}
# Combination (67.0, 47.0, 5.0) has multiple resulting parameters with counts: {(66.0, 49.0): 1, (67.0, 50.0): 1}
# Combination (67.0, 50.0, 5.0) has multiple resulting parameters with counts: {(68.0, 52.0): 2, (67.0, 52.0): 1}
# Combination (67.0, 51.0, 3.0) has multiple resulting parameters with counts: {(68.0, 52.0): 1, (68.0, 53.0): 1}
# Combination (67.0, 52.0, 3.0) has multiple resulting parameters with counts: {(69.0, 54.0): 1, (68.0, 54.0): 1}
# Combination (67.0, 65.0, 5.0) has multiple resulting parameters with counts: {(74.0, 68.0): 1, (73.0, 68.0): 2}
# Combination (68.0, 24.0, 3.0) has multiple resulting parameters with counts: {(59.0, 26.0): 1, (60.0, 25.0): 1}
# Combination (68.0, 25.0, 1.0) has multiple resulting parameters with counts: {(59.0, 26.0): 1, (60.0, 26.0): 2}
# Combination (68.0, 32.0, 3.0) has multiple resulting parameters with counts: {(62.0, 33.0): 1, (63.0, 34.0): 4}
# Combination (68.0, 45.0, 3.0) has multiple resulting parameters with counts: {(67.0, 47.0): 1, (67.0, 46.0): 1}
# Combination (68.0, 52.0, 3.0) has multiple resulting parameters with counts: {(70.0, 54.0): 1, (69.0, 53.0): 1}
# Combination (68.0, 70.0, 3.0) has multiple resulting parameters with counts: {(76.0, 72.0): 1, (75.0, 72.0): 1}
# Combination (68.0, 75.0, 4.0) has multiple resulting parameters with counts: {(77.0, 77.0): 1, (78.0, 77.0): 2}
# Combination (69.0, 17.0, 4.0) has multiple resulting parameters with counts: {(59.0, 19.0): 1, (58.0, 18.0): 1}
# Combination (69.0, 18.0, 1.0) has multiple resulting parameters with counts: {(59.0, 19.0): 1, (58.0, 20.0): 1}
# Combination (69.0, 21.0, 3.0) has multiple resulting parameters with counts: {(60.0, 22.0): 1, (60.0, 23.0): 1}
# Combination (69.0, 23.0, 3.0) has multiple resulting parameters with counts: {(60.0, 25.0): 1, (61.0, 25.0): 1}
# Combination (69.0, 54.0, 5.0) has multiple resulting parameters with counts: {(72.0, 56.0): 1, (71.0, 56.0): 1}
# Combination (69.0, 66.0, 6.0) has multiple resulting parameters with counts: {(75.0, 69.0): 1, (76.0, 68.0): 1}
# Combination (69.0, 74.0, 5.0) has multiple resulting parameters with counts: {(78.0, 76.0): 1, (79.0, 76.0): 1}
# Combination (69.0, 76.0, 3.0) has multiple resulting parameters with counts: {(79.0, 78.0): 1, (79.0, 77.0): 1}
# Combination (70.0, 34.0, 3.0) has multiple resulting parameters with counts: {(65.0, 36.0): 3, (65.0, 35.0): 1}
# Combination (70.0, 37.0, 4.0) has multiple resulting parameters with counts: {(67.0, 39.0): 1, (66.0, 39.0): 1}
# Combination (70.0, 43.0, 3.0) has multiple resulting parameters with counts: {(69.0, 45.0): 1, (68.0, 45.0): 1}
# Combination (70.0, 49.0, 4.0) has multiple resulting parameters with counts: {(71.0, 51.0): 1, (70.0, 51.0): 1}
# Combination (70.0, 50.0, 5.0) has multiple resulting parameters with counts: {(71.0, 52.0): 1, (71.0, 53.0): 1}
# Combination (70.0, 54.0, 4.0) has multiple resulting parameters with counts: {(72.0, 56.0): 1, (73.0, 56.0): 1}
# Combination (71.0, 25.0, 3.0) has multiple resulting parameters with counts: {(62.0, 26.0): 1, (63.0, 26.0): 1}
# Combination (71.0, 42.0, 3.0) has multiple resulting parameters with counts: {(69.0, 43.0): 1, (69.0, 44.0): 1}
# Combination (71.0, 47.0, 2.0) has multiple resulting parameters with counts: {(71.0, 48.0): 1, (71.0, 49.0): 1}
# ...
# Combination (397.0, 70.0, 5.0) has multiple resulting parameters with counts: {(403.0, 69.0): 2, (404.0, 68.0): 1}
# Combination (397.0, 71.0, 5.0) has multiple resulting parameters with counts: {(404.0, 70.0): 1, (405.0, 70.0): 1}
# Combination (398.0, 35.0, 4.0) has multiple resulting parameters with counts: {(392.0, 34.0): 1, (392.0, 33.0): 1}
# Combination (398.0, 66.0, 6.0) has multiple resulting parameters with counts: {(404.0, 65.0): 1, (403.0, 65.0): 1}
# Combination (400.0, 37.0, 4.0) has multiple resulting parameters with counts: {(395.0, 36.0): 1, (395.0, 35.0): 1}
# Combination (400.0, 68.0, 5.0) has multiple resulting parameters with counts: {(406.0, 67.0): 2, (406.0, 66.0): 1}
# Combination (401.0, 38.0, 3.0) has multiple resulting parameters with counts: {(397.0, 36.0): 1, (396.0, 37.0): 1}
# Combination (401.0, 61.0, 3.0) has multiple resulting parameters with counts: {(405.0, 59.0): 1, (404.0, 60.0): 1}
# Combination (401.0, 67.0, 5.0) has multiple resulting parameters with counts: {(406.0, 66.0): 3, (406.0, 65.0): 1}
# Combination (401.0, 71.0, 6.0) has multiple resulting parameters with counts: {(408.0, 71.0): 1, (409.0, 70.0): 1}
# Combination (402.0, 43.0, 4.0) has multiple resulting parameters with counts: {(399.0, 42.0): 1, (400.0, 42.0): 1}
# Combination (402.0, 73.0, 4.0) has multiple resulting parameters with counts: {(409.0, 71.0): 1, (410.0, 71.0): 1}
# Combination (403.0, 69.0, 5.0) has multiple resulting parameters with counts: {(409.0, 68.0): 1, (410.0, 67.0): 1, (410.0, 68.0): 2}
# Combination (404.0, 52.0, 3.0) has multiple resulting parameters with counts: {(405.0, 51.0): 1, (404.0, 50.0): 1}
# Combination (404.0, 55.0, 7.0) has multiple resulting parameters with counts: {(406.0, 54.0): 1, (405.0, 54.0): 1}
# Combination (404.0, 60.0, 6.0) has multiple resulting parameters with counts: {(407.0, 59.0): 1, (408.0, 60.0): 1}
# Combination (404.0, 69.0, 5.0) has multiple resulting parameters with counts: {(411.0, 68.0): 1, (410.0, 67.0): 1}
# Combination (404.0, 75.0, 5.0) has multiple resulting parameters with counts: {(412.0, 74.0): 1, (413.0, 74.0): 1}
# Combination (405.0, 40.0, 4.0) has multiple resulting parameters with counts: {(401.0, 39.0): 1, (401.0, 38.0): 1}
# Combination (405.0, 50.0, 4.0) has multiple resulting parameters with counts: {(404.0, 48.0): 1, (405.0, 48.0): 1}
# Combination (406.0, 74.0, 5.0) has multiple resulting parameters with counts: {(414.0, 73.0): 2, (415.0, 73.0): 1}
# Combination (406.0, 75.0, 5.0) has multiple resulting parameters with counts: {(415.0, 73.0): 1, (415.0, 74.0): 1}
# Combination (407.0, 38.0, 3.0) has multiple resulting parameters with counts: {(403.0, 37.0): 1, (402.0, 36.0): 1}
# Combination (407.0, 53.0, 7.0) has multiple resulting parameters with counts: {(408.0, 53.0): 1, (408.0, 52.0): 1}
# Combination (407.0, 60.0, 5.0) has multiple resulting parameters with counts: {(411.0, 59.0): 1, (410.0, 59.0): 1}
# Combination (408.0, 52.0, 7.0) has multiple resulting parameters with counts: {(408.0, 52.0): 1, (409.0, 51.0): 1}
# Combination (408.0, 53.0, 3.0) has multiple resulting parameters with counts: {(409.0, 52.0): 1, (408.0, 51.0): 1}
# Combination (408.0, 70.0, 4.0) has multiple resulting parameters with counts: {(414.0, 69.0): 1, (415.0, 69.0): 1}
# Combination (409.0, 49.0, 1.0) has multiple resulting parameters with counts: {(409.0, 47.0): 1, (408.0, 47.0): 1}
# Combination (409.0, 50.0, 7.0) has multiple resulting parameters with counts: {(409.0, 50.0): 1, (409.0, 49.0): 1}
# Combination (409.0, 51.0, 7.0) has multiple resulting parameters with counts: {(410.0, 50.0): 1, (409.0, 50.0): 1}
# Combination (409.0, 61.0, 3.0) has multiple resulting parameters with counts: {(413.0, 59.0): 1, (412.0, 59.0): 1}
# Combination (409.0, 70.0, 3.0) has multiple resulting parameters with counts: {(416.0, 68.0): 1, (415.0, 69.0): 1}
# Combination (410.0, 50.0, 7.0) has multiple resulting parameters with counts: {(410.0, 50.0): 1, (409.0, 49.0): 1}
# Combination (410.0, 68.0, 5.0) has multiple resulting parameters with counts: {(416.0, 67.0): 1, (416.0, 66.0): 1}
# Combination (411.0, 69.0, 5.0) has multiple resulting parameters with counts: {(417.0, 68.0): 1, (418.0, 68.0): 1}
# Combination (412.0, 74.0, 5.0) has multiple resulting parameters with counts: {(421.0, 73.0): 1, (420.0, 73.0): 1}
# Combination (415.0, 67.0, 5.0) has multiple resulting parameters with counts: {(421.0, 67.0): 1, (421.0, 66.0): 1}
# Combination (415.0, 73.0, 5.0) has multiple resulting parameters with counts: {(423.0, 73.0): 1, (423.0, 72.0): 1}
# Combination (416.0, 55.0, 6.0) has multiple resulting parameters with counts: {(418.0, 55.0): 1, (418.0, 54.0): 1}
# Combination (416.0, 63.0, 5.0) has multiple resulting parameters with counts: {(420.0, 62.0): 1, (421.0, 62.0): 1}
# Combination (416.0, 63.0, 6.0) has multiple resulting parameters with counts: {(421.0, 62.0): 1, (420.0, 62.0): 1}
# Combination (416.0, 66.0, 5.0) has multiple resulting parameters with counts: {(421.0, 65.0): 5, (421.0, 66.0): 1}
# Combination (417.0, 57.0, 3.0) has multiple resulting parameters with counts: {(420.0, 55.0): 1, (419.0, 56.0): 1}
# Combination (417.0, 62.0, 3.0) has multiple resulting parameters with counts: {(421.0, 60.0): 1, (421.0, 61.0): 1}
# Combination (417.0, 64.0, 5.0) has multiple resulting parameters with counts: {(421.0, 63.0): 3, (422.0, 63.0): 1}
# Combination (417.0, 65.0, 6.0) has multiple resulting parameters with counts: {(423.0, 64.0): 1, (422.0, 64.0): 1}
# Combination (418.0, 43.0, 2.0) has multiple resulting parameters with counts: {(415.0, 42.0): 1, (415.0, 41.0): 1}
# Combination (419.0, 45.0, 2.0) has multiple resulting parameters with counts: {(417.0, 43.0): 1, (417.0, 44.0): 1}
# Combination (420.0, 55.0, 5.0) has multiple resulting parameters with counts: {(422.0, 54.0): 1, (421.0, 55.0): 1}
# Combination (421.0, 48.0, 3.0) has multiple resulting parameters with counts: {(420.0, 47.0): 1, (420.0, 46.0): 2}
# Combination (421.0, 61.0, 5.0) has multiple resulting parameters with counts: {(425.0, 61.0): 1, (425.0, 60.0): 1}
# Combination (421.0, 65.0, 5.0) has multiple resulting parameters with counts: {(426.0, 64.0): 4, (427.0, 65.0): 1, (427.0, 64.0): 1}
# Combination (421.0, 68.0, 5.0) has multiple resulting parameters with counts: {(428.0, 68.0): 1, (427.0, 67.0): 1}
# Combination (422.0, 48.0, 5.0) has multiple resulting parameters with counts: {(422.0, 48.0): 1, (421.0, 48.0): 2}
# Combination (422.0, 51.0, 5.0) has multiple resulting parameters with counts: {(422.0, 51.0): 2, (422.0, 50.0): 1}
# Combination (422.0, 51.0, 6.0) has multiple resulting parameters with counts: {(423.0, 50.0): 1, (422.0, 51.0): 1}
# Combination (422.0, 54.0, 5.0) has multiple resulting parameters with counts: {(424.0, 53.0): 1, (423.0, 53.0): 1}
# Combination (422.0, 54.0, 6.0) has multiple resulting parameters with counts: {(423.0, 53.0): 2, (424.0, 53.0): 1}
# Combination (422.0, 61.0, 4.0) has multiple resulting parameters with counts: {(426.0, 60.0): 1, (425.0, 59.0): 1}
# Combination (422.0, 72.0, 5.0) has multiple resulting parameters with counts: {(429.0, 71.0): 1, (430.0, 71.0): 1}
# Combination (423.0, 50.0, 4.0) has multiple resulting parameters with counts: {(423.0, 49.0): 1, (422.0, 48.0): 1}
# Combination (423.0, 53.0, 3.0) has multiple resulting parameters with counts: {(423.0, 51.0): 1, (424.0, 52.0): 1}
# Combination (424.0, 47.0, 2.0) has multiple resulting parameters with counts: {(422.0, 46.0): 1, (422.0, 45.0): 1, (423.0, 45.0): 1}
# Combination (424.0, 47.0, 3.0) has multiple resulting parameters with counts: {(423.0, 46.0): 1, (422.0, 45.0): 1}
# Combination (424.0, 53.0, 4.0) has multiple resulting parameters with counts: {(424.0, 52.0): 1, (425.0, 52.0): 1}
# Combination (424.0, 67.0, 5.0) has multiple resulting parameters with counts: {(429.0, 66.0): 1, (430.0, 66.0): 2}
# Combination (425.0, 49.0, 3.0) has multiple resulting parameters with counts: {(424.0, 47.0): 1, (425.0, 48.0): 1}
# Combination (425.0, 49.0, 4.0) has multiple resulting parameters with counts: {(425.0, 48.0): 1, (424.0, 48.0): 1}
# Combination (425.0, 52.0, 4.0) has multiple resulting parameters with counts: {(426.0, 50.0): 1, (426.0, 51.0): 2}
# Combination (425.0, 61.0, 5.0) has multiple resulting parameters with counts: {(428.0, 60.0): 1, (429.0, 60.0): 1}
# Combination (426.0, 58.0, 6.0) has multiple resulting parameters with counts: {(429.0, 58.0): 1, (429.0, 57.0): 1}
# Combination (427.0, 46.0, 4.0) has multiple resulting parameters with counts: {(425.0, 44.0): 1, (425.0, 45.0): 1}
# Combination (427.0, 63.0, 5.0) has multiple resulting parameters with counts: {(431.0, 62.0): 2, (432.0, 62.0): 1}
# Combination (427.0, 65.0, 5.0) has multiple resulting parameters with counts: {(432.0, 65.0): 2, (432.0, 64.0): 3}
# Combination (428.0, 60.0, 5.0) has multiple resulting parameters with counts: {(432.0, 60.0): 1, (431.0, 59.0): 1}
# Combination (428.0, 67.0, 3.0) has multiple resulting parameters with counts: {(434.0, 65.0): 1, (433.0, 65.0): 1}
# Combination (429.0, 72.0, 5.0) has multiple resulting parameters with counts: {(436.0, 72.0): 1, (437.0, 71.0): 1}
# Combination (430.0, 40.0, 5.0) has multiple resulting parameters with counts: {(426.0, 39.0): 1, (427.0, 39.0): 1}
# Combination (430.0, 49.0, 2.0) has multiple resulting parameters with counts: {(429.0, 48.0): 1, (429.0, 47.0): 1}
# Combination (430.0, 66.0, 5.0) has multiple resulting parameters with counts: {(435.0, 66.0): 1, (435.0, 65.0): 1}
# Combination (431.0, 62.0, 5.0) has multiple resulting parameters with counts: {(436.0, 61.0): 1, (435.0, 61.0): 1}
# Combination (431.0, 63.0, 5.0) has multiple resulting parameters with counts: {(436.0, 62.0): 2, (435.0, 63.0): 1}
# Combination (431.0, 72.0, 5.0) has multiple resulting parameters with counts: {(438.0, 71.0): 2, (439.0, 72.0): 1}
# Combination (432.0, 60.0, 5.0) has multiple resulting parameters with counts: {(435.0, 59.0): 1, (435.0, 60.0): 1}
# Combination (432.0, 64.0, 5.0) has multiple resulting parameters with counts: {(437.0, 63.0): 2, (436.0, 63.0): 1, (437.0, 64.0): 1}
# Combination (433.0, 66.0, 4.0) has multiple resulting parameters with counts: {(439.0, 65.0): 1, (438.0, 65.0): 1}
# Combination (434.0, 41.0, 3.0) has multiple resulting parameters with counts: {(431.0, 39.0): 1, (430.0, 40.0): 1}
# Combination (434.0, 61.0, 5.0) has multiple resulting parameters with counts: {(438.0, 61.0): 1, (438.0, 60.0): 3}
# Combination (434.0, 65.0, 6.0) has multiple resulting parameters with counts: {(439.0, 65.0): 1, (440.0, 65.0): 1}
# Combination (436.0, 59.0, 5.0) has multiple resulting parameters with counts: {(439.0, 58.0): 1, (440.0, 58.0): 1, (440.0, 59.0): 1}
# Combination (436.0, 62.0, 5.0) has multiple resulting parameters with counts: {(440.0, 62.0): 2, (440.0, 61.0): 1}
# Combination (437.0, 64.0, 5.0) has multiple resulting parameters with counts: {(442.0, 64.0): 1, (442.0, 63.0): 1}
# Combination (437.0, 69.0, 5.0) has multiple resulting parameters with counts: {(444.0, 68.0): 1, (443.0, 69.0): 1}
# Combination (437.0, 71.0, 5.0) has multiple resulting parameters with counts: {(444.0, 70.0): 1, (445.0, 71.0): 1}
# Combination (438.0, 71.0, 5.0) has multiple resulting parameters with counts: {(446.0, 71.0): 1, (446.0, 70.0): 1}
# Combination (439.0, 58.0, 5.0) has multiple resulting parameters with counts: {(441.0, 58.0): 1, (442.0, 58.0): 1}
# Combination (440.0, 61.0, 5.0) has multiple resulting parameters with counts: {(444.0, 60.0): 1, (444.0, 61.0): 1}
# Combination (440.0, 62.0, 4.0) has multiple resulting parameters with counts: {(444.0, 61.0): 1, (445.0, 61.0): 1}
# Combination (441.0, 58.0, 5.0) has multiple resulting parameters with counts: {(444.0, 57.0): 1, (444.0, 58.0): 1}
# Combination (441.0, 59.0, 5.0) has multiple resulting parameters with counts: {(444.0, 59.0): 1, (445.0, 59.0): 2}
# Combination (441.0, 65.0, 5.0) has multiple resulting parameters with counts: {(446.0, 65.0): 1, (446.0, 64.0): 1}
# Combination (443.0, 67.0, 5.0) has multiple resulting parameters with counts: {(449.0, 67.0): 1, (449.0, 66.0): 1}
# Combination (444.0, 57.0, 5.0) has multiple resulting parameters with counts: {(447.0, 57.0): 1, (446.0, 56.0): 1}
# Combination (444.0, 61.0, 5.0) has multiple resulting parameters with counts: {(448.0, 61.0): 2, (448.0, 60.0): 2}
# Combination (444.0, 64.0, 4.0) has multiple resulting parameters with counts: {(449.0, 64.0): 2, (449.0, 63.0): 1}
# Combination (444.0, 70.0, 5.0) has multiple resulting parameters with counts: {(451.0, 70.0): 1, (451.0, 69.0): 1}
# Combination (445.0, 60.0, 5.0) has multiple resulting parameters with counts: {(449.0, 59.0): 1, (448.0, 60.0): 1}
# Combination (445.0, 63.0, 5.0) has multiple resulting parameters with counts: {(449.0, 62.0): 1, (449.0, 63.0): 1}
# Combination (446.0, 62.0, 5.0) has multiple resulting parameters with counts: {(450.0, 62.0): 2, (451.0, 62.0): 1}
# Combination (448.0, 51.0, 5.0) has multiple resulting parameters with counts: {(448.0, 51.0): 1, (449.0, 50.0): 1}
# Combination (448.0, 60.0, 6.0) has multiple resulting parameters with counts: {(451.0, 60.0): 1, (452.0, 60.0): 2}
# Combination (448.0, 61.0, 5.0) has multiple resulting parameters with counts: {(452.0, 61.0): 2, (452.0, 60.0): 2}
# Combination (450.0, 56.0, 5.0) has multiple resulting parameters with counts: {(453.0, 55.0): 1, (452.0, 56.0): 1}
# Combination (450.0, 62.0, 5.0) has multiple resulting parameters with counts: {(454.0, 61.0): 2, (455.0, 62.0): 1}
# Combination (450.0, 68.0, 5.0) has multiple resulting parameters with counts: {(457.0, 67.0): 1, (457.0, 68.0): 1}
# Combination (451.0, 60.0, 5.0) has multiple resulting parameters with counts: {(454.0, 59.0): 1, (455.0, 60.0): 1}
# Combination (451.0, 71.0, 5.0) has multiple resulting parameters with counts: {(459.0, 70.0): 1, (458.0, 70.0): 1}
# Combination (452.0, 60.0, 3.0) has multiple resulting parameters with counts: {(455.0, 59.0): 1, (456.0, 59.0): 1}
# Combination (452.0, 61.0, 5.0) has multiple resulting parameters with counts: {(456.0, 60.0): 2, (456.0, 61.0): 1}
# Combination (453.0, 57.0, 6.0) has multiple resulting parameters with counts: {(456.0, 57.0): 1, (455.0, 57.0): 1}
# Combination (453.0, 63.0, 6.0) has multiple resulting parameters with counts: {(457.0, 63.0): 1, (458.0, 63.0): 2}
# Combination (454.0, 58.0, 5.0) has multiple resulting parameters with counts: {(456.0, 58.0): 1, (457.0, 58.0): 2}
# Combination (454.0, 63.0, 3.0) has multiple resulting parameters with counts: {(459.0, 63.0): 1, (458.0, 62.0): 1}
# Combination (455.0, 62.0, 5.0) has multiple resulting parameters with counts: {(459.0, 62.0): 1, (459.0, 61.0): 1}
# Combination (456.0, 61.0, 4.0) has multiple resulting parameters with counts: {(459.0, 60.0): 1, (460.0, 61.0): 1}
# Combination (456.0, 64.0, 5.0) has multiple resulting parameters with counts: {(461.0, 64.0): 1, (461.0, 63.0): 1}
# Combination (457.0, 58.0, 5.0) has multiple resulting parameters with counts: {(460.0, 58.0): 1, (459.0, 58.0): 1}
# Combination (458.0, 59.0, 5.0) has multiple resulting parameters with counts: {(461.0, 59.0): 1, (462.0, 59.0): 1}
# Combination (458.0, 61.0, 5.0) has multiple resulting parameters with counts: {(462.0, 60.0): 1, (463.0, 61.0): 1, (462.0, 61.0): 1}
# Combination (459.0, 57.0, 5.0) has multiple resulting parameters with counts: {(462.0, 57.0): 1, (462.0, 56.0): 1}
# Combination (459.0, 62.0, 5.0) has multiple resulting parameters with counts: {(463.0, 62.0): 1, (464.0, 62.0): 1}
# Combination (459.0, 70.0, 5.0) has multiple resulting parameters with counts: {(466.0, 70.0): 1, (467.0, 70.0): 1}
# Combination (460.0, 60.0, 5.0) has multiple resulting parameters with counts: {(463.0, 60.0): 1, (464.0, 60.0): 1}
# Combination (461.0, 48.0, 5.0) has multiple resulting parameters with counts: {(461.0, 48.0): 1, (460.0, 48.0): 1}
# Combination (461.0, 51.0, 4.0) has multiple resulting parameters with counts: {(461.0, 51.0): 1, (462.0, 50.0): 1}
# Combination (462.0, 50.0, 3.0) has multiple resulting parameters with counts: {(462.0, 50.0): 1, (462.0, 49.0): 1}
# Combination (464.0, 60.0, 5.0) has multiple resulting parameters with counts: {(467.0, 60.0): 1, (468.0, 60.0): 1}

# %%
# how often does may state action pairs have multiple resulting params
# in data_ check what combinations of columns 0, 1, 2 have many different combinations of col 4,5

# %%
print(data.shape)
print(achieved.shape)
# Out:
# (100000, 4)
# (186, 6)

# %%
unique_pv = np.unique(np.vstack([states_pv, next_states_pv]), axis=0)

# %%
q = [.25, .5, .75, .95, .99]
print(f"Observed state space quantiles, Q = {q}\n")
for i in range(1, 8):
    print(f"Action = {i}")
    bla = data_[data_[:, 2] == i]
    print(f"Number of observations: {bla.shape[0]}")
    p_quants = np.quantile(bla[:, 0], q)
    v_quants = np.quantile(bla[:, 1], q)
    print(f"P Quantiles: {list(p_quants)}")
    print(f"V Quantiles: {list(v_quants)}\n")
# Out:
# Observed state space quantiles, Q = [0.25, 0.5, 0.75, 0.95, 0.99]
#
# Action = 1
# Number of observations: 11614
# P Quantiles: [164.0, 196.0, 221.0, 329.35000000000036, 369.0]
# V Quantiles: [38.0, 45.0, 49.0, 57.0, 62.0]
#
# Action = 2
# Number of observations: 9080
# P Quantiles: [178.0, 203.0, 226.0, 314.0, 399.2099999999991]
# V Quantiles: [39.0, 46.0, 51.0, 58.0, 63.0]
#
# Action = 3
# Number of observations: 21760
# P Quantiles: [159.0, 198.0, 237.0, 343.0499999999993, 415.0]
# V Quantiles: [36.0, 46.0, 52.0, 72.0, 86.0]
#
# Action = 4
# Number of observations: 13003
# P Quantiles: [174.0, 205.0, 238.0, 362.0, 429.0]
# V Quantiles: [43.0, 50.0, 57.0, 77.0, 88.0]
#
# Action = 5
# Number of observations: 22742
# P Quantiles: [167.0, 208.0, 263.0, 397.0, 451.0]
# V Quantiles: [48.0, 56.0, 67.0, 86.0, 93.0]
#
# Action = 6
# Number of observations: 9394
# P Quantiles: [183.0, 206.0, 232.0, 354.0, 430.0]
# V Quantiles: [48.0, 53.0, 60.0, 80.0, 89.0]
#
# Action = 7
# Number of observations: 12407
# P Quantiles: [173.0, 207.0, 257.0, 377.0, 443.0]
# V Quantiles: [50.0, 57.0, 72.0, 96.0, 98.0]

# %%
data = utils.read_data('medium')
states = data[:, 0]
actions = data[:, 1]
rewards = data[:, 2]

next_states = data[:, 3]
states_pv = np.array([get_pv(s) for s in states])
next_states_pv = np.array([get_pv(s) for s in next_states])
actions = actions.reshape(-1, 1)     
rewards = rewards.reshape(-1, 1)  

data_ = np.hstack([states_pv, actions, next_states_pv, rewards])

# next add self absorbing states, from EDA, we know that 
# big reward is obtained at p = 466
p_values = np.arange(466, 500)          
v_values = np.arange(100)               
actions = np.arange(1, 8)                

p_grid, v_grid, action_grid = np.meshgrid(p_values, v_values, actions, indexing='ij')

p_flat = p_grid.ravel()
v_flat = v_grid.ravel()
action_flat = action_grid.ravel()

# Create the new rows by stacking the columns [p, v, action, p, v, 0]
new_rows = np.column_stack((p_flat, v_flat, action_flat, p_flat, v_flat, np.zeros_like(p_flat)))

data_ = np.vstack([data_, new_rows])

states_pv = data_[:, [0,1]]
actions = data_[:, 2]
next_states_pv = data_[:, [3,4]]
rewards = data_[:, -1]
unique_rewards = np.unique(rewards)
reward_to_idx = {reward: idx for idx, reward in enumerate(unique_rewards)}
idx_to_reward = {idx: reward for reward, idx in reward_to_idx.items()}
reward_idx = np.array([reward_to_idx[r] for r in rewards])

# %%
data_
# Out:
# array([[ 200.,   49.,    3.,  200.,   49.,  -25.],
#        [ 200.,   49.,    2.,  200.,   48., -100.],
#        [ 200.,   48.,    3.,  199.,   48.,  -25.],
#        ...,
#        [ 499.,   99.,    5.,  499.,   99.,    0.],
#        [ 499.,   99.,    6.,  499.,   99.,    0.],
#        [ 499.,   99.,    7.,  499.,   99.,    0.]])

# %%
data.shape
# Out:
# (100000, 4)

# %%
data_.shape
# Out:
# (123800, 6)
